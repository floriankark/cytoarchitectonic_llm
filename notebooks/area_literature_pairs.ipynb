# %%
import pandas as pd

file_path = '../data/raw/Zyto_Projektliste.xlsx'
df = pd.read_excel(file_path, header=1)
# Out:
# /Users/floriankark/Desktop/cytoarchitectonic_llm/.venv/lib/python3.12/site-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)

# %%
# Anzeigen der ersten paar Zeilen des DataFrames
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307 entries, 0 to 306
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Major brain parts          294 non-null    object
#  1   Brain region global        294 non-null    object
#  2   Lobes                      286 non-null    object
#  3   Brain region local         288 non-null    object
#  4   Functionality              192 non-null    object
#  5   Structure                  284 non-null    object
#  6   Structure name published   291 non-null    object
#  7   Structure summary names    89 non-null     object
#  8   Project name internal      292 non-null    object
#  9   Structure name intern      288 non-null    object
#  10  Brodmann area              114 non-null    float64
#  11  Investigator               292 non-null    object
#  12  ShortReference             283 non-null    object
# ...

# %%
df.head(10)
# Out:
#   Major brain parts Brain region global         Lobes  \
# 0     telencephalon     cerebral cortex       overall
# 1     telencephalon     cerebral cortex       overall
# 2     telencephalon     cerebral cortex       overall
# 3     telencephalon     cerebral cortex       overall
# 4     telencephalon     cerebral cortex       overall
# 5     telencephalon     cerebral cortex  frontal lobe
# 6     telencephalon     cerebral cortex  frontal lobe
# 7     telencephalon     cerebral cortex  frontal lobe
# 8     telencephalon     cerebral cortex  frontal lobe
# 9     telencephalon     cerebral cortex  frontal lobe
#
#         Brain region local    Functionality         Structure  \
# 0                  overall              NaN               NaN
# 1                  overall              NaN               NaN
# 2                  overall              NaN               NaN
# 3                  overall              NaN               NaN
# ...

# %%
# sources:
# https://pmc.ncbi.nlm.nih.gov/articles/PMC7014920/
# scince direct
# Springer Nature Link
# https://academic.oup.com/cercor/article/29/3/1305/5248530
# frontiers

# %%
# unique values in column Reference
df['Reference'].unique()[37]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[44], line 2
#       1 # unique values in column Reference
# ----> 2 df['Reference'].unique()[37]
#
# IndexError: index 37 is out of bounds for axis 0 with size 37

# %%
df['ShortReference'].unique()
# Out:
# array(['Amunts et al., 2020, Science', 'Geyer et al., 1996, Nature',
#        'in preparation', 'Ruan et al. 2018, Brain Struct Funct',
#        'Amunts et al., 1999, J Comp Neurol und Amunts et al., 2004, NeuroImage',
#        'Bludau et al., 2014, NeuroImage', 'Henssen et al., 2016, Cortex',
#        'Wojtasik et al., 2020. Frontiers in Neuroanatomy', nan,
#        'Grodzinsky et al., 2020, Brain Structure and Function',
#        'Kurth et al., 2009, Cereb Cortex',
#        'Palomero-Gallagher et al., 2015, NeuroImage',
#        'Palomero-Gallagher et al., 2018, Cerebral Cortex',
#        'Palomero-Gallagher, Kedo et al., 2020, Brain Struct Funct, Amunts et al., 2005, Anat Embryol',
#        'Amunts et al., 2005, Anat Embryol',
#        'Palomero-Gallagher, Kedo et al., 2020, Brain Struct Funct',
#        'Amunts et al., 2000, NeuroImage',
#        'Kujovic et al., 2013, Brain Struct Funct',
#        'Malikovic et al., 2016, Brain Struct Funct',
# ...
